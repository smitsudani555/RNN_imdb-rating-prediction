# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From d:\DL_RNN\rnn_venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
sent=['The glass of milk',
    'the glass of juice',
    'the cup of the tea',
    'i am a good reader',
    'i am a good gymnasium',
    'see you soon'
]

# %%
voc_size=10000

# %%
one_hot_repr=[one_hot(word,voc_size) for word in sent]
one_hot_repr
# Out:
# [[2329, 6273, 965, 3841],
#  [2329, 6273, 965, 5067],
#  [2329, 8247, 965, 2329, 7175],
#  [2273, 7699, 8661, 8020, 1384],
#  [2273, 7699, 8661, 8020, 9389],
#  [2701, 3845, 6847]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import  pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_doc=pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
embedded_doc
# Out:
# array([[   0,    0,    0,    0, 2329, 6273,  965, 3841],
#        [   0,    0,    0,    0, 2329, 6273,  965, 5067],
#        [   0,    0,    0, 2329, 8247,  965, 2329, 7175],
#        [   0,    0,    0, 2273, 7699, 8661, 8020, 1384],
#        [   0,    0,    0, 2273, 7699, 8661, 8020, 9389],
#        [   0,    0,    0,    0,    0, 2701, 3845, 6847]])

# %%
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From d:\DL_RNN\rnn_venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_doc)
# Out:
# 1/1 [==============================] - 0s 345ms/step
# array([[[ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [-0.02444453, -0.04361647,  0.03489368, -0.03787602,
#           0.02038454,  0.0130262 , -0.03918128, -0.03842449,
#          -0.01018203,  0.02806393],
#         [-0.04385542,  0.0342934 ,  0.01148901, -0.03484005,
#           0.02494968, -0.02723792, -0.02264353, -0.02229619,
#          -0.01604805, -0.00925022],
#         [ 0.01920924, -0.0019199 ,  0.01747807,  0.00480824,
#          -0.0102108 , -0.04851462,  0.01716531,  0.03048832,
#           0.01174849, -0.02696382],
#         [ 0.00567095, -0.00197939, -0.000877  ,  0.04370013,
#          -0.03118887, -0.04917857,  0.01692858,  0.01277203,
#          -0.01277614, -0.00635351]],
#
#        [[ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [-0.02444453, -0.04361647,  0.03489368, -0.03787602,
#           0.02038454,  0.0130262 , -0.03918128, -0.03842449,
#          -0.01018203,  0.02806393],
#         [-0.04385542,  0.0342934 ,  0.01148901, -0.03484005,
#           0.02494968, -0.02723792, -0.02264353, -0.02229619,
#          -0.01604805, -0.00925022],
#         [ 0.01920924, -0.0019199 ,  0.01747807,  0.00480824,
#          -0.0102108 , -0.04851462,  0.01716531,  0.03048832,
#           0.01174849, -0.02696382],
#         [ 0.0239817 , -0.03331591, -0.00320726,  0.04019538,
#          -0.01883556, -0.00666016, -0.01732375,  0.03381372,
#          -0.04879586,  0.01876323]],
#
#        [[ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [-0.02444453, -0.04361647,  0.03489368, -0.03787602,
#           0.02038454,  0.0130262 , -0.03918128, -0.03842449,
#          -0.01018203,  0.02806393],
#         [ 0.00425367,  0.03469659,  0.03614571, -0.03375212,
#          -0.03512249, -0.02093474, -0.04644489,  0.02021438,
#           0.00962839,  0.03780479],
#         [ 0.01920924, -0.0019199 ,  0.01747807,  0.00480824,
#          -0.0102108 , -0.04851462,  0.01716531,  0.03048832,
#           0.01174849, -0.02696382],
#         [-0.02444453, -0.04361647,  0.03489368, -0.03787602,
#           0.02038454,  0.0130262 , -0.03918128, -0.03842449,
#          -0.01018203,  0.02806393],
#         [ 0.02347393,  0.01004237, -0.00183983,  0.02988261,
#           0.00791796,  0.03952042,  0.01062291, -0.0056914 ,
#          -0.02460892, -0.04416985]],
#
#        [[ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.04295863, -0.00990076, -0.01782185,  0.03924974,
#          -0.02370614,  0.03821031, -0.02281724, -0.03978659,
#           0.04450903, -0.02676609],
#         [-0.04337862, -0.04625435, -0.02925656,  0.04872547,
#           0.0099838 ,  0.03219068, -0.02390931,  0.04866377,
#           0.0328279 ,  0.00161232],
#         [-0.03884733,  0.0261711 ,  0.011148  ,  0.04150319,
#          -0.0315425 , -0.0322177 ,  0.0041227 ,  0.03476093,
#           0.0351132 ,  0.00435749],
#         [ 0.04485066, -0.03757137, -0.00692706,  0.02620205,
#           0.00835394,  0.00975301,  0.04807058, -0.04930556,
#          -0.00794628, -0.03562337],
#         [ 0.00909177,  0.04671462, -0.0483507 ,  0.032439  ,
#          -0.03388165,  0.01990995,  0.04235284,  0.0006664 ,
#           0.04531239, -0.00602444]],
#
#        [[ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.04295863, -0.00990076, -0.01782185,  0.03924974,
#          -0.02370614,  0.03821031, -0.02281724, -0.03978659,
#           0.04450903, -0.02676609],
#         [-0.04337862, -0.04625435, -0.02925656,  0.04872547,
#           0.0099838 ,  0.03219068, -0.02390931,  0.04866377,
#           0.0328279 ,  0.00161232],
#         [-0.03884733,  0.0261711 ,  0.011148  ,  0.04150319,
#          -0.0315425 , -0.0322177 ,  0.0041227 ,  0.03476093,
#           0.0351132 ,  0.00435749],
#         [ 0.04485066, -0.03757137, -0.00692706,  0.02620205,
#           0.00835394,  0.00975301,  0.04807058, -0.04930556,
#          -0.00794628, -0.03562337],
#         [-0.03110012,  0.04970905, -0.0059666 , -0.00962553,
#           0.04652986,  0.01637533,  0.01761374, -0.04177229,
#          -0.03556123, -0.02098005]],
#
#        [[ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.01956588,  0.02911866, -0.03009321,  0.04264754,
#          -0.0303699 ,  0.02592285,  0.02118723,  0.02983054,
#          -0.03666165, -0.02450736],
#         [ 0.00253008,  0.04142039,  0.00938689, -0.04877361,
#          -0.02115823,  0.01644218, -0.00446116, -0.04866948,
#           0.01715609,  0.03237836],
#         [-0.03487759, -0.04693068,  0.01359716,  0.00978687,
#          -0.02443453, -0.00157311,  0.02995408,  0.0493103 ,
#           0.02914062,  0.02623245],
#         [ 0.00622848, -0.02680773, -0.00896523, -0.03218434,
#          -0.03546082, -0.00276202,  0.02718543,  0.03522449,
#           0.02341273, -0.03737462]]], dtype=float32)

# %%
embedded_doc[0]
# Out:
# array([   0,    0,    0,    0, 2329, 6273,  965, 3841])

# %%
model.predict(embedded_doc[0])
# Out:
# 1/1 [==============================] - 0s 76ms/step
# array([[ 0.01956588,  0.02911866, -0.03009321,  0.04264754, -0.0303699 ,
#          0.02592285,  0.02118723,  0.02983054, -0.03666165, -0.02450736],
#        [ 0.01956588,  0.02911866, -0.03009321,  0.04264754, -0.0303699 ,
#          0.02592285,  0.02118723,  0.02983054, -0.03666165, -0.02450736],
#        [ 0.01956588,  0.02911866, -0.03009321,  0.04264754, -0.0303699 ,
#          0.02592285,  0.02118723,  0.02983054, -0.03666165, -0.02450736],
#        [ 0.01956588,  0.02911866, -0.03009321,  0.04264754, -0.0303699 ,
#          0.02592285,  0.02118723,  0.02983054, -0.03666165, -0.02450736],
#        [-0.02444453, -0.04361647,  0.03489368, -0.03787602,  0.02038454,
#          0.0130262 , -0.03918128, -0.03842449, -0.01018203,  0.02806393],
#        [-0.04385542,  0.0342934 ,  0.01148901, -0.03484005,  0.02494968,
#         -0.02723792, -0.02264353, -0.02229619, -0.01604805, -0.00925022],
#        [ 0.01920924, -0.0019199 ,  0.01747807,  0.00480824, -0.0102108 ,
#         -0.04851462,  0.01716531,  0.03048832,  0.01174849, -0.02696382],
#        [ 0.00567095, -0.00197939, -0.000877  ,  0.04370013, -0.03118887,
#         -0.04917857,  0.01692858,  0.01277203, -0.01277614, -0.00635351]],
#       dtype=float32)
